# %% [markdown]
# #### EDA

# %%
# Basic
# Basic Neuron Output Process

# Inputs (x), Weights (w), and Bias (b)
x = np.array([1.2, 0.5, -0.8]) 
w = np.array([0.8, 0.2, 0.1])
b = -0.5

# Step 1: Linear calculation (z = w*x + b)
z = np.dot(w, x) + b  

# Step 2: Activation Function (Using ReLU here)
a = np.maximum(0, z) 

print(f"Neuron Output: {a}")


# data['Gender'].value_counts()
val = df.groupby(['Gender', 'Exited']).size()/len(df['Exited'])*100

# Plot Graph
# val.unstack().plot(kind='bar')
ax = val.unstack().plot(kind='bar', color=['green', 'red'], alpha=0.45)
plt.ylabel("Percentage")
plt.title("Exited vs Gender")
plt.legend(loc='best')
plt.yticks(np.arange(0, 50, 5))
plt.grid(alpha=0.4)

for label in ax.containers:
    ax.bar_label(label)

plt.show()

# For ALl 
for col in df[['Geography', 'Gender', 'HasCrCard', 'IsActiveMember', 'Tenure']].columns:
    val = df.groupby([col, 'Exited']).size()/len(df['Exited'])*100
    
    # Plot Graph
    plt.figure(figsize=(8,5))
    ax = val.unstack().plot(kind='bar', color = ['green', 'red'], alpha=0.7)
    plt.ylabel("Percentage")
    plt.title(f"Exited vs {col}")
    plt.legend(loc='best')
    plt.grid(alpha=0.4)
    
    for label in ax.containers:
        ax.bar_label(label)
    plt.tight_layout()
    plt.show()

# 1. Geography:
#    * Half Germany People Churn
#    * France is Least Churn with only 20%
#    * Spain is Least Churn By Percentage 20%

# 2. Gender:
#    * Female Churn More Total 11.43 (25.11%) of there Population
#    * Male Churn Less Total 8.49 (15.58%) of there Population
  
# 3. Credit Card:
#    * No Credit Card Churn Ratio ==> 3.8 : 1
#    * Credit Card Churn Ratio ==> 3.95 : 1
#    * Credit Card Churn (8.11%) More

# 4. Is Active Member:
#    * Active Ratio     ==> 2.7 : 1
#    * Not Active Ratio ==> 6: 1
#    * Not Active Churn (5.67%) More

# 5. Tenure:
#    * 0 Year is Lowest Churn
#    * 1st Year is Highest Churn

# Activation Functions

# Raw scores calculated by the neuron (z = wx + b)
raw_scores = np.array([-3.0, 0.0, 2.0, 5.0])

# 1. Linear (Outputs the exact same array)
linear_out = raw_scores 

# 2. ReLU (Turns negatives to 0, keeps positives)
relu_out = np.maximum(0, raw_scores)

# 3. Sigmoid (Squashes to probabilities between 0 and 1)
sigmoid_out = 1 / (1 + np.exp(-raw_scores))

print(f"Raw:     {raw_scores}")
print(f"Linear:  {linear_out}")
print(f"ReLU:    {relu_out}")
print(f"Sigmoid: {np.round(sigmoid_out, 3)}\nAt Last sigmoid {np.round(sigmoid_out, 3)}")

a = np.round(sigmoid_out, 3)

Result_long = []
for i in range(len(a)):
    if a[i] > 0.5:
        Result = 'Buy'
        Result_long.append(Result)
    else:
        Result = 'Not Buy'
        Result_long.append(Result)

# Short
Result = ['Buy' if v > 0.5 else 'Not Buy' for v in a]

# Short and Fast
Result_fast = np.where(a > 0.5, 'Buy', 'Not Buy')

print('By Long Iteration     : ', Result_long)
print('By List Comprehension : ', Result)
print('By Numpy Where        : ', Result_fast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # Basic
#       2 # Basic Neuron Output Process
#       3
#       4 # Inputs (x), Weights (w), and Bias (b)
# ----> 5 x = np.array([1.2, 0.5, -0.8])
#       6 w = np.array([0.8, 0.2, 0.1])
#       7 b = -0.5
#
# NameError: name 'np' is not defined

# %% [markdown]
# ## Library

# %%
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
    import statistics as st
    import copy
    
    from sklearn.preprocessing import OneHotEncoder as ohe, LabelEncoder as le, StandardScaler as ss
    from sklearn.model_selection import train_test_split as tts, cross_val_score as cvs, GridSearchCV as gscv, RandomizedSearchCV as rscv
    from sklearn.tree import DecisionTreeClassifier as dtc
    from sklearn.metrics import mean_absolute_error as mae, mean_squared_error as mse, root_mean_squared_error as rmse, r2_score as r2, confusion_matrix as cm, accuracy_score as AS
    from sklearn.ensemble import RandomForestClassifier as rfc
    from sklearn.pipeline import Pipeline
    
    import keras
    from keras.layers import Dense, Input
    from keras.models import Sequential
    
    from scikeras.wrappers import KerasClassifier 
    from scikeras.wrappers import KerasClassifier as kc

# %% [markdown]
# ## Data

# %%
# Data
data = pd.read_csv(r"D:\COURSE\DATA SCIENCE FULL COURSE BY UDEMY\SECTION 8 Deep Learning\Deep Learning - Resources-20260311T130352Z-3-001\Deep Learning - Resources\Churn_Modelling.csv")

# Copy
df = copy.deepcopy(data)
df.drop(columns=['CustomerId', 'RowNumber', 'Surname'], axis=1, inplace=True)

df.head()

# Fill Missing Values
df['Gender'] = df['Gender'].ffill() 
df['Age'] = df['Age'].fillna(df['Age'].median())
df.isna().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## ML Implimentation

# %%
# Split in X and Y 
x = df.drop(['Exited'], axis=1).values
y = df[['Exited']].values

# Feature Encoding
encoder = le()
x[:, 1] = encoder.fit_transform(x[: ,1])
x[:, 2] = encoder.fit_transform(x[: ,2])

# Train Test Split
x_train, x_test, y_train, y_test = tts(x, y, test_size=0.2, random_state=42)

# Feature Scaling
scaler = ss()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Classic Decision Tree ML
model = dtc()
model.fit(x_train, y_train)
dtc_pred = model.predict(x_test)

# Create Confusion Matrix
matrix = cm(y_test, dtc_pred)
print(matrix)

# Accuracy Score
Acc = AS(y_test, dtc_pred)
print('Accuracy Scoer : ', round(Acc*100, 3))
# Out:
# [[1363  244]
#  [ 197  196]]
# Accuracy Scoer :  77.95

# %%
# Classic Random Forest Tree ML
model = rfc(n_estimators=200 , random_state=42)
model.fit(x_train, y_train)
rfc_pred = model.predict(x_test)

# Create Confusion Matrix
matrix = cm(y_test, rfc_pred)
print(matrix)

# Accuracy Score
Acc = AS(y_test, rfc_pred)
print('Accuracy Scoer : ', round(Acc*100), 3)
# Out:
# C:\Users\puruj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [[1557   50]
#  [ 216  177]]
# Accuracy Scoer :  87 3

# %% [markdown]
# ## ANN

# %% [markdown]
# #### 1. Model Initilization

# %%
model = Sequential()

# Create Input Layer 
model.add(
    Input(shape=(10,)))

# Create First Hidden Layer
model.add(
    Dense(
        units=6,
        kernel_initializer='he_uniform',
        activation='relu'
    ))

# Create 2nd Hidden Layer
model.add(
    Dense(
        units=6,
        kernel_initializer='he_uniform',
        activation='relu',
        bias_initializer='zeros'
    ))

# Crate 3rd Hidden Layer
model.add(
    Dense(
        units=6,
        kernel_initializer='he_uniform',
        activation='relu',
        bias_initializer='zeros'
    ))

# Create Output Layer
model.add(
    Dense(
        units=1, 
        kernel_initializer='he_uniform',
        activation='sigmoid',
        bias_initializer='zeros'
    ))


# Model Compiling
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Model Fit The training data And Testing Data
model.fit(x_train, y_train, batch_size=10, epochs=200)

# Prediction
y_pred = (model.predict(x_test)).astype(int) # Convert probability to class

# Accuracy
print("Accuracy Score:", AS(y_test, y_pred))

df_test = pd.DataFrame({
'CreditScore':[800],
'Geography':[0],
'Gender':[1],
'Age':[35],
'Tenure':[5],
'Balance':[10000],
'NumOfProducts':[2],
'HasCrCard':[1],
'IsActiveMember':[1],
'EstimatedSalary':[100000]
})

# Only scale
df_test = scaler.transform(df_test)

# New Prediction
new_predict = model.predict(df_test)
if new_predict > 0.5:
    print("Customer will Exit")
else:
    print("Customer will Stay")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7796 - loss: 0.5318
# Epoch 2/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8051 - loss: 0.4403
# Epoch 3/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8138 - loss: 0.4128
# Epoch 4/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8171 - loss: 0.3976
# Epoch 5/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8235 - loss: 0.3884
# Epoch 6/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8250 - loss: 0.3824
# Epoch 7/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8260 - loss: 0.3776
# Epoch 8/200
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8468 - loss: 0.3740
# Epoch 9/200
# ...

# %% [markdown]
# #### 2.Build Classifier Basic

# %%
def build_classifier():
    classifier=Sequential()
    classifier.add(Input(shape=(10,)))
    classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    classifier.add(Dense(units=1, kernel_initializer='he_uniform', activation='sigmoid'))

    classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return classifier

model = KerasClassifier(build_fn=build_classifier, batch_size=10, epochs=10)
accuracy = cvs(estimator=model, X=x_train, y=y_train, cv=10, n_jobs=-1)

mean1 = accuracy.mean()
varience = accuracy.std()

print('Mean of acc: ', mean1)
print('Accuracy   : ', accuracy)
print('Varience   : ', varience)
# Out:
# Mean of acc:  0.8411249999999999
# Accuracy   :  [0.8625  0.8475  0.79625 0.83375 0.84375 0.865   0.8475  0.8275  0.83625
#  0.85125]
# Varience   :  0.018695336985462444

# %% [markdown]
# #### 3. HPO

# %%
def build_classifier():
    model = Sequential()
    model.add(Input(shape=(10,)))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=1, kernel_initializer='he_uniform', activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

classifier = kc(model=build_classifier)

parameter = {
    'batch_size' :[10, 16, 32],
    'epochs' : [5,6]
} # 4 Combination

grid_search = gscv(estimator=classifier, param_grid=parameter, scoring='accuracy', n_jobs=-1, cv=5) # 4 * 5 = 20 Times Model Will Run
grid_search.fit(x_train, y_train)

grid_search.best_score_, grid_search.best_params_

# %%
def build_classifier():
    model = Sequential()
    model.add(Input(shape=(10,)))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))
    model.add(Dense(units=1, kernel_initializer='he_uniform', activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

classifier = kc(model=build_classifier)

parameter = {
    'batch_size' :[10, 16, 32, 64],
    'epochs' : [5, 10, 30, 60]
} # 4 Combination

grid_search = gscv(estimator=classifier, param_grid=parameter, scoring='accuracy', n_jobs=-1, cv=10) # 4 * 5 = 20 Times Model Will Run
grid_search.fit(x_train, y_train)

grid_search.best_score_, grid_search.best_params_
# Out:
# Epoch 1/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7781 - loss: 0.6370
# Epoch 2/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.5623
# Epoch 3/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.5289
# Epoch 4/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.5153
# Epoch 5/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7945 - loss: 0.5103
# Epoch 6/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.5086
# Epoch 7/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.5081
# Epoch 8/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7945 - loss: 0.5080
# Epoch 9/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7986 - loss: 0.4806
# Epoch 10/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8126 - loss: 0.4552
# Epoch 11/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8171 - loss: 0.4451
# ...

# %%
# Best Model 
model = Sequential()
model.add(Input(shape=(10,)))
model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', bias_initializer='zeros'))
model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', bias_initializer='zeros'))
model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', bias_initializer='zeros'))
model.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', bias_initializer='zeros'))
model.add(Dense(units=1, kernel_initializer='he_uniform', activation='sigmoid', bias_initializer='zeros'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=16, epochs=60)
# Out:
# Epoch 1/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7928 - loss: 0.5402
# Epoch 2/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8014 - loss: 0.4764
# Epoch 3/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8166 - loss: 0.4383
# Epoch 4/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8279 - loss: 0.4098
# Epoch 5/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8366 - loss: 0.3940
# Epoch 6/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8419 - loss: 0.3843
# Epoch 7/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8438 - loss: 0.3780
# Epoch 8/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8456 - loss: 0.3737
# Epoch 9/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8481 - loss: 0.3702
# Epoch 10/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8489 - loss: 0.3666
# Epoch 11/60
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8509 - loss: 0.3643
# ...
